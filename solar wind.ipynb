# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
t_naught = 2*10**6

# %%
r_s = (2*10**6)*(0.181/1)*(t_naught/(2*10**6))**(-1)

# %%
a_naught = 180*(t_naught/(2*10**6))**(1/2)

# %%
def stellar_wind(r):
    r *= 10**6
    return a_naught*np.exp(3/2)*np.exp((-2*r_s)/r)

# %%
x = np.linspace(1,160)
y = stellar_wind(x)
plt.plot(x,y,label='2x10^6K')
plt.title('Solar Wind')
plt.xlabel('r')
plt.ylabel('u(r) kms^-1')
plt.legend()
plt.show()
