# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
t_naught = 2.3*10**6

# %%
r_s = (2*10**11)*(0.181/1)*(t_naught/(2*10**6))**(-1)

# %%
a_naught = 180*(t_naught/(2*10**6))**(1/2)

# %%
def stellar_wind(r):
    r *= 10**11
    return a_naught*np.exp(3/2)*np.exp((-2*r_s)/r)

# %%
def stellar_wind_large_radii(r):
    r *= 10**11
    return 2*a_naught*np.sqrt(np.log(r/r_s))

# %%
x = np.linspace(1,160)
y = stellar_wind(x)
plt.plot(x,y)
plt.title('Stellar Wind of GJ 1132')
plt.xlabel('r')
plt.ylabel('u(r) kms^-1')
plt.show()
