# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams.update({'font.size': 20})
plt.rcParams['figure.figsize'] = [20, 10]

# %%
#rotation period for M2.5-6.0 V stars
#applies for GJ 1132, GJ 3053, K2-18, GJ 1214
def rotation_period_M2(T):
    return (T-0.012)/0.061

x = np.linspace(1,10)
y = rotation_period_M2(x)

plt.plot(x,y, label="rotation period of M2.5-6.0 V stars")
plt.legend(loc= 'lower right', bbox_to_anchor=(1.29, +0.12))
plt.title('Rotation Period v. Age in Gyr')
plt.xlabel('Age (Gyr)')
plt.ylabel('Rotation Period (days)')
# Out:
# Text(0, 0.5, 'Rotation Period (days)')

# %%
#rotation period for M0 V stars
#applies for Kepler 138, K2-3
def rotation_period_M1(T):
    return ((T-0.365)/0.019)**(1/1.457)

x = np.linspace(1,10)
y = rotation_period_M1(x)

plt.plot(x,y, label="rotation period of M0V stars")
plt.legend(loc= 'lower right', bbox_to_anchor=(1.29, +0.12))
plt.title('Rotation Period v. Age in Gyr')
plt.xlabel('Age (Gyr)')
plt.ylabel('Rotation Period (days)')
# Out:
# Text(0, 0.5, 'Rotation Period (days)')

# %%
#rotation period for K-type stars
#applies for 55 Cnc, GJ 9827, GJ 97658
def rotation_period_K(T):
    return 25*((T/4.6)**1/2)

x = np.linspace(1,10)
y = rotation_period_K(x)

plt.plot(x,y, label="rotation period of K-Type stars")
plt.legend(loc= 'lower right', bbox_to_anchor=(1.29, +0.12))
plt.title('Rotation Period v. Age in Gyr')
plt.xlabel('Age (Gyr)')
plt.ylabel('Rotation Period (days)')
# Out:
# Text(0, 0.5, 'Rotation Period (days)')

# %%
#I COMBINED THE CORONAL TEMPERATURE EQUATION WITH THE ROTATION PERIOD FUNCTION FOR EACH SCENARIO

# %%
#coronal temperature for M2.5-6.0 V stars and st_rot > 18.9
#applies for GJ1132, GJ 3053, K2-18, GJ 1214
def coronal_temp_M2_rot1(T):
    return 1.5*(27/((T-0.012)/0.061))**1.2

x = np.linspace(1,10)
y = coronal_temp_M2_rot1(x)

plt.plot(x,y, label="coronal temperature of M2.5-6.0 V stars and st_rot > 18.9")
plt.legend(loc= 'lower right', bbox_to_anchor=(1.29, +0.12))
plt.title('coronal temperature v. Age in Gyr')
plt.xlabel('Age (Gyr)')
plt.ylabel('coronal temperature (MK)')
# Out:
# Text(0, 0.5, 'coronal temperature (MK)')

# %%
#coronal temperature for M0V stars and st_rot > 18.9
#applies Kepler 138, K2-3
def coronal_temp_M1_rot1(T):
    return 1.5*(27/((T-0.365)/0.019)**(1/1.457))**1.2

x = np.linspace(1,10)
y = coronal_temp_M1_rot1(x)

plt.plot(x,y, label="coronal temperature for M0V stars and st_rot > 18.9")
plt.legend(loc= 'lower right', bbox_to_anchor=(1.29, +0.12))
plt.title('Coronal Temperature v. Age in Gyr')
plt.xlabel('Age (Gyr)')
plt.ylabel('Coronal Temperature (MK)')
# Out:
# Text(0, 0.5, 'Coronal Temperature (MK)')

# %%
#coronal temperature for K type stars and st_rot > 18.9
#applies for 55Cnc, GJ 97658

def coronal_temp_K_rot1(T):
    return 1.5*(27/(25*((T/4.6)**1/2)))**1.2

x = np.linspace(1,10)
y = coronal_temp_K_rot1(x)

plt.plot(x,y, label="coronal temperature for K type stars and st_rot > 18.9")
plt.legend(loc= 'lower right', bbox_to_anchor=(1.29, +0.12))
plt.title('Coronal Temperature v. Age in Gyr')
plt.xlabel('Age (Gyr)')
plt.ylabel('Coronal Temperature (MK)')
# Out:
# Text(0, 0.5, 'Coronal Temperature (MK)')

# %%
#coronal temperature for K type stars and st_rot < 18.9
#applies for GJ 9827

def coronal_temp_K_rot1(T):
    return 1.98*(27/(25*((T/4.6)**1/2)))**0.37

x = np.linspace(1,10)
y = coronal_temp_K_rot1(x)

plt.plot(x,y, label="coronal temperature for K type stars and st_rot < 18.9")
plt.legend(loc= 'lower right', bbox_to_anchor=(1.29, +0.12))
plt.title('Coronal Temperature v. Age in Gyr')
plt.xlabel('Age (Gyr)')
plt.ylabel('Coronal Temperature (MK)')
# Out:
# Text(0, 0.5, 'Coronal Temperature (MK)')

# %%
#CALCULATING WIND VELOCITY NOW!

# %%
T2_table = np.genfromtxt('/Users/kalgi/Desktop/STELLARWIND.csv', delimiter=",", usecols=(1,4,7,16,19,25,26,27,35,36,37,28,38,31), skip_header=2) 
T2_table = np.transpose(T2_table)

T2_table_onlynames = np.genfromtxt('/Users/kalgi/Desktop/STELLARWIND.csv', delimiter=",", usecols=(2),skip_header=2, dtype=str) 
T2_table_onlynames = np.transpose(T2_table_onlynames)
# Read the parameters of the table

names = T2_table_onlynames #names of the planets
plt_mass=T2_table[0] #in earth mass
plt_rad=T2_table[1] #in earth radii
plt_den=T2_table[2] #in g/cm^3
st_mass=T2_table[3] #in solar mass
st_rot=T2_table[4] #in days
st_cotemp= T2_table[5] #in MK
orb_rad= T2_table[6] #in km
plt_rad_km= T2_table[7] #in km
M_a_gs= T2_table[8] #Mass loss in g/s
M_a_gGyr= T2_table[9] #Mass loss in g/1Gyr
M_a_MEGyr= T2_table[10] #Mass loss in Earth Mass/Gyr
plt_mass_kg= T2_table[11] #planet mass in kg
M_a_percent = T2_table[12] #mass percent of atmosphere lost in relation to planets mass (atmospere lost/planet mass X100)
p_atm= T2_table[13] #percent Earth atmosphere

# %%
#FOR GJ3053

def wind_velocity_M2_rot1_GJ3053(T):
    return 2*(180*((1.5*(27/((T-0.012)/0.061))**1.2)*10**6/(2*10**6))**(1/2))*np.log(14002560*10**5/((2*10**11)*(0.179/1)*((1.5*(27/((T-0.012)/0.061))**1.2)*10**6/(2*10**6))**(-1)))**0.5 

x = np.linspace(1,10)
y = wind_velocity_M2_rot1_GJ3053(x)

plt.plot(x,y, label="wind velocity of GJ 3053")
plt.legend(loc= 'lower right', bbox_to_anchor=(1.29, +0.12))
plt.title('wind velocity v. Age in Gyr')
plt.xlabel('Age (Gyr)')
plt.ylabel('wind velocity (km/s)')
# Out:
# Text(0, 0.5, 'wind velocity (km/s)')

# %%
#FOR K2-18

def wind_velocity_M2_rot1_K218(T):
    return 2*(180*((1.5*(27/((T-0.012)/0.061))**1.2)*10**6/(2*10**6))**(1/2))*np.log(21377840*10**5/((2*10**11)*(0.359/1)*((1.5*(27/((T-0.012)/0.061))**1.2)*10**6/(2*10**6))**(-1)))**0.5 

x = np.linspace(1,10)
y = wind_velocity_M2_rot1_K218(x)

plt.plot(x,y, label="wind velocity of K2-18")
plt.legend(loc= 'lower right', bbox_to_anchor=(1.29, +0.12))
plt.title('wind velocity v. Age in Gyr')
plt.xlabel('Age (Gyr)')
plt.ylabel('wind velocity (km/s)')
# Out:
# Text(0, 0.5, 'wind velocity (km/s)')

# %%
#For Kepler-138

def wind_velocity_M1_rot1_Kepler138(T):
    return 2*(180*((1.5*(27/((T-0.365)/0.019)**(1/1.457))**1.2)*10**6/(2*10**6))**(1/2))*np.log(18999200*10**5/((2*10**11)*(0.521/1)*((1.5*(27/((T-0.365)/0.019)**(1/1.457))**1.2)*10**6/(2*10**6))**(-1)))**0.5 

x = np.linspace(1,10)
y = wind_velocity_M1_rot1_Kepler138(x)

plt.plot(x,y, label="wind velocity of Kepler-138")
plt.legend(loc= 'lower right', bbox_to_anchor=(1.29, +0.12))
plt.title('wind velocity v. Age in Gyr')
plt.xlabel('Age (Gyr)')
plt.ylabel('wind velocity (km/s)')
# Out:
# Text(0, 0.5, 'wind velocity (km/s)')

# %%
#For K2-3d

def wind_velocity_M1_rot1_K23d(T):
    return 2*(180*((1.5*(27/((T-0.365)/0.019)**(1/1.457))**1.2)*10**6/(2*10**6))**(1/2))*np.log(31266400*10**5/((2*10**11)*(0.601/1)*((1.5*(27/((T-0.365)/0.019)**(1/1.457))**1.2)*10**6/(2*10**6))**(-1)))**0.5 

x = np.linspace(1,10)
y = wind_velocity_M1_rot1_K23d(x)

plt.plot(x,y, label="wind velocity of K2-3d")
plt.legend(loc= 'lower right', bbox_to_anchor=(1.29, +0.12))
plt.title('wind velocity v. Age in Gyr')
plt.xlabel('Age (Gyr)')
plt.ylabel('wind velocity (km/s)')
# Out:
# Text(0, 0.5, 'wind velocity (km/s)')

# %%
#For K2-3c

def wind_velocity_M1_rot1_K23c(T):
    return 2*(180*((1.5*(27/((T-0.365)/0.019)**(1/1.457))**1.2)*10**6/(2*10**6))**(1/2))*np.log(21138480*10**5/((2*10**11)*(0.601/1)*((1.5*(27/((T-0.365)/0.019)**(1/1.457))**1.2)*10**6/(2*10**6))**(-1)))**0.5 

x = np.linspace(1,10)
y = wind_velocity_M1_rot1_K23c(x)

plt.plot(x,y, label="wind velocity of K2-3c")
plt.legend(loc= 'lower right', bbox_to_anchor=(1.29, +0.12))
plt.title('wind velocity v. Age in Gyr')
plt.xlabel('Age (Gyr)')
plt.ylabel('wind velocity (km/s)')
# Out:
# Text(0, 0.5, 'wind velocity (km/s)')

# %%
#For GJ9827

def wind_velocity_K_rot2_GJ9827(T):
    return 2*(180*((1.98*(27/(25*((T/4.6)**1/2)))**0.37)*10**6/(2*10**6))**(1/2))*np.log(8228000*10**5/((2*10**11)*(0.606/1)*((1.98*(27/(25*((T/4.6)**1/2)))**0.37)*10**6/(2*10**6))**(-1)))**0.5 

x = np.linspace(1,10)
y = wind_velocity_K_rot2_GJ9827(x)

plt.plot(x,y, label="wind velocity of GJ9827")
plt.legend(loc= 'lower right', bbox_to_anchor=(1.29, +0.12))
plt.title('wind velocity v. Age in Gyr')
plt.xlabel('Age (Gyr)')
plt.ylabel('wind velocity (km/s)')
# Out:
# Text(0, 0.5, 'wind velocity (km/s)')

# %%
#For GJ97658

def wind_velocity_K_rot1_GJ97658(T):
    return 2*(180*((1.5*(27/(25*((T/4.6)**1/2)))**1.2)*10**6/(2*10**6))**(1/2))*np.log(11968000*10**5/((2*10**11)*(0.85/1)*((1.5*(27/(25*((T/4.6)**1/2)))**1.2)*10**6/(2*10**6))**(-1)))**0.5 

x = np.linspace(1,10)
y = wind_velocity_K_rot1_GJ97658(x)

plt.plot(x,y, label="wind velocity of GJ97658")
plt.legend(loc= 'lower right', bbox_to_anchor=(1.29, +0.12))
plt.title('wind velocity v. Age in Gyr')
plt.xlabel('Age (Gyr)')
plt.ylabel('wind velocity (km/s)')
# Out:
# Text(0, 0.5, 'wind velocity (km/s)')

# %%
#For GJ1132

def wind_velocity_M2_rot1_GJ1132(T):
    return (180*((1.5*(27/((T-0.012)/0.061))**1.2)*10**6/(2*10**6))**(1/2))*np.exp(3/2)*np.exp((-2*((2*10**11)*(0.181/1)*((1.5*(27/((T-0.012)/0.061))**1.2)*10**6/(2*10**6))**(-1)))/(2288880*10**5))

x = np.linspace(1,10)
y = wind_velocity_M2_rot1_GJ1132(x)

plt.plot(x,y, label="wind velocity of GJ1132")
plt.legend(loc= 'lower right', bbox_to_anchor=(1.29, +0.12))
plt.title('wind velocity v. Age in Gyr')
plt.xlabel('Age (Gyr)')
plt.ylabel('wind velocity (km/s)')
# Out:
# Text(0, 0.5, 'wind velocity (km/s)')

# %%
#For GJ1214

def wind_velocity_M2_rot1_GJ1214(T):
    return (180*((1.5*(27/((T-0.012)/0.061))**1.2)*10**6/(2*10**6))**(1/2))*np.exp(3/2)*np.exp((-2*((2*10**11)*(0.15/1)*((1.5*(27/((T-0.012)/0.061))**1.2)*10**6/(2*10**6))**(-1)))/(2094400*10**5))

x = np.linspace(1,10)
y = wind_velocity_M2_rot1_GJ1214(x)

plt.plot(x,y, label="wind velocity of GJ1214")
plt.legend(loc= 'lower right', bbox_to_anchor=(1.29, +0.12))
plt.title('wind velocity v. Age in Gyr')
plt.xlabel('Age (Gyr)')
plt.ylabel('wind velocity (km/s)')
# Out:
# Text(0, 0.5, 'wind velocity (km/s)')

# %%
#For 55Cnc

def wind_velocity_K_rot1_55Cnc(T):
    return (180*((1.5*(27/(25*((T/4.6)**1/2)))**1.2)*10**6/(2*10**6))**(1/2))*np.exp(3/2)*np.exp((-2*((2*10**11)*(0.905/1)*((1.5*(27/(25*((T/4.6)**1/2)))**1.2)*10**6/(2*10**6))**(-1)))/(2303840*10**5))

x = np.linspace(1,10)
y = wind_velocity_K_rot1_55Cnc(x)

plt.plot(x,y, label="wind velocity of 55Cnc")
plt.legend(loc= 'lower right', bbox_to_anchor=(1.29, +0.12))
plt.title('wind velocity v. Age in Gyr')
plt.xlabel('Age (Gyr)')
plt.ylabel('wind velocity (km/s)')
# Out:
# Text(0, 0.5, 'wind velocity (km/s)')

# %%
x = np.linspace(1,10)
y = wind_velocity_M2_rot1_GJ3053(x)

x1 = np.linspace(1,10)
y1 = wind_velocity_M2_rot1_K218(x1)

x2 = np.linspace(1,10)
y2 = wind_velocity_M1_rot1_Kepler138(x2)

x3 = np.linspace(1,10)
y3 = wind_velocity_M1_rot1_K23d(x3)

x5 = np.linspace(1,10)
y5 = wind_velocity_K_rot2_GJ9827(x5)

x6 = np.linspace(1,10)
y6 = wind_velocity_K_rot1_GJ97658(x6)

x7 = np.linspace(1,10)
y7 = wind_velocity_M2_rot1_GJ1132(x7)

x8 = np.linspace(1,10)
y8 = wind_velocity_M2_rot1_GJ1214(x8)

x9 = np.linspace(1,10)
y9 = wind_velocity_K_rot1_55Cnc(x9)

x4 = np.linspace(1,10)
y4 = wind_velocity_M1_rot1_K23c(x4)

axes= plt.axes()

plt.plot(x5,y5, label="GJ 9827")
plt.plot(x9,y9,label= "55 Cnc")
plt.plot(x6,y6, label= "GJ 97658")
plt.plot(x1,y1, label='K2-18')
plt.plot(x3,y3,label="K2-3d")
plt.plot(x7,y7,label='GJ 1132')
plt.plot(x8,y8,label='GJ 1214')
plt.plot(x2,y2,label='Kepler-138')
plt.plot(x,y,label='GJ-3053')
plt.plot(x4,y4,label="K2-3c")

plt.legend(loc= 'lower right', bbox_to_anchor=(1.29, +0.12))
plt.title('Wind Velocity v. Age')
plt.xlabel('Age (Gyr)')
plt.ylabel('Wind velocity (kms$^-1$)')
# Out:
# Text(0, 0.5, 'Wind velocity (kms$^-1$)')

# %%
#CALCULATING WIND DENSITY
#wind_density= ((3.3E5*(orb_rad*10**5/r_sun)**-2 + 4.16E6*(orb_rad*10**5/r_sun)**-4 + 8.0E7*(orb_rad*10**5/r_sun)**-6)*(M_H/2)*((st_rot/P_sun)**0.6))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-5f2d2a00232d> in <module>()
#       1 #CALCULATING WIND DENSITY
# ----> 2 wind_density= ((3.3E5*(orb_rad*10**5/r_sun)**-2 + 4.16E6*(orb_rad*10**5/r_sun)**-4 + 8.0E7*(orb_rad*10**5/r_sun)**-6)*(M_H/2)*((st_rot/P_sun)**0.6))
#
# NameError: name 'r_sun' is not defined

# %%
M_H= 1.6726231E-24 #mass of the proton in grams
P_sun= 27.2 #rotation period of Sun in day
r_sun=6.96E10 #radius of the sun in cm

# %%
#wind density for GJ3053

def wind_density_GJ3053(T):
    return ((3.3E5*(14002560*10**5/r_sun)**-2 + 4.16E6*(14002560*10**5/r_sun)**-4 + 8.0E7*(14002560*10**5/r_sun)**-6)*(M_H/2)*((P_sun/((T-0.012)/0.061))**0.6))

x = np.linspace(1,10)
y = wind_density_GJ3053(x)

plt.plot(x,y, label="wind density of GJ3053")
plt.legend(loc= 'lower right', bbox_to_anchor=(1.29, +0.12))
plt.title('wind density v. Age')
plt.xlabel('Age (Gyr)')
plt.ylabel('wind density(g/cm^3)')
# Out:
# Text(0, 0.5, 'wind density(g/cm^3)')

# %%
#wind density for K2-18

def wind_density_K218(T):
    return ((3.3E5*(21377840*10**5/r_sun)**-2 + 4.16E6*(21377840*10**5/r_sun)**-4 + 8.0E7*(21377840*10**5/r_sun)**-6)*(M_H/2)*((P_sun/((T-0.012)/0.061))**0.6))

x = np.linspace(1,10)
y = wind_density_K218(x)

plt.plot(x,y, label="wind density of K218")
plt.legend(loc= 'lower right', bbox_to_anchor=(1.29, +0.12))
plt.title('wind density v. Age')
plt.xlabel('Age (Gyr)')
plt.ylabel('wind density(g/cm^3)')
# Out:
# Text(0, 0.5, 'wind density(g/cm^3)')

# %%
#wind density for Kepler-138

def wind_density_Kepler138(T):
    return ((3.3E5*(18999200*10**5/r_sun)**-2 + 4.16E6*(18999200*10**5/r_sun)**-4 + 8.0E7*(18999200*10**5/r_sun)**-6)*(M_H/2)*((P_sun/(((T-0.365)/0.019)**(1/1.457)))**0.6))

x = np.linspace(1,10)
y = wind_density_Kepler138(x)

plt.plot(x,y, label="wind density of Kepler-138")
plt.legend(loc= 'lower right', bbox_to_anchor=(1.29, +0.12))
plt.title('wind density v. Age')
plt.xlabel('Age (Gyr)')
plt.ylabel('wind density(g/cm^3)')
# Out:
# Text(0, 0.5, 'wind density(g/cm^3)')

# %%
#wind density for K2-3d

def wind_density_K23d(T):
    return ((3.3E5*(31266400*10**5/r_sun)**-2 + 4.16E6*(31266400*10**5/r_sun)**-4 + 8.0E7*(31266400*10**5/r_sun)**-6)*(M_H/2)*((P_sun/(((T-0.365)/0.019)**(1/1.457)))**0.6))

x = np.linspace(1,10)
y = wind_density_K23d(x)

plt.plot(x,y, label="wind density of K2-3d")
plt.legend(loc= 'lower right', bbox_to_anchor=(1.29, +0.12))
plt.title('wind density v. Age')
plt.xlabel('Age (Gyr)')
plt.ylabel('wind density(g/cm^3)')
# Out:
# Text(0, 0.5, 'wind density(g/cm^3)')

# %%
#wind density for K2-3c

def wind_density_K23c(T):
    return ((3.3E5*(21138480*10**5/r_sun)**-2 + 4.16E6*(21138480*10**5/r_sun)**-4 + 8.0E7*(21138480*10**5/r_sun)**-6)*(M_H/2)*((P_sun/(((T-0.365)/0.019)**(1/1.457)))**0.6))

x = np.linspace(1,10)
y = wind_density_K23c(x)

plt.plot(x,y, label="wind density of K2-3d")
plt.legend(loc= 'lower right', bbox_to_anchor=(1.29, +0.12))
plt.title('wind density v. Age')
plt.xlabel('Age (Gyr)')
plt.ylabel('wind density(g/cm^3)')
# Out:
# Text(0, 0.5, 'wind density(g/cm^3)')

# %%
#wind density for GJ-9827

def wind_density_GJ9827(T):
    return ((3.3E5*(8228000*10**5/r_sun)**-2 + 4.16E6*(8228000*10**5/r_sun)**-4 + 8.0E7*(8228000*10**5/r_sun)**-6)*(M_H/2)*((P_sun/(25*((T/4.6)**1/2)))**0.6))


x = np.linspace(1,10)
y = wind_density_GJ9827(x)

plt.plot(x,y, label="wind density of GJ-9827")
plt.legend(loc= 'lower right', bbox_to_anchor=(1.29, +0.12))
plt.title('wind density v. Age')
plt.xlabel('Age (Gyr)')
plt.ylabel('wind density(g/cm^3)')
# Out:
# Text(0, 0.5, 'wind density(g/cm^3)')

# %%
#wind density for GJ-97658

def wind_density_GJ97658(T):
    return ((3.3E5*(11968000*10**5/r_sun)**-2 + 4.16E6*(11968000*10**5/r_sun)**-4 + 8.0E7*(11968000*10**5/r_sun)**-6)*(M_H/2)*((P_sun/(25*((T/4.6)**1/2)))**0.6))


x = np.linspace(1,10)
y = wind_density_GJ97658(x)

plt.plot(x,y, label="wind density of GJ-97658")
plt.legend(loc= 'lower right', bbox_to_anchor=(1.29, +0.12))
plt.title('wind density v. Age')
plt.xlabel('Age (Gyr)')
plt.ylabel('wind density(g/cm^3)')
# Out:
# Text(0, 0.5, 'wind density(g/cm^3)')

# %%
#wind density for GJ1132

def wind_density_GJ1132(T):
    return ((3.3E5*(2288880*10**5/r_sun)**-2 + 4.16E6*(2288880*10**5/r_sun)**-4 + 8.0E7*(2288880*10**5/r_sun)**-6)*(M_H/2)*((P_sun/((T-0.012)/0.061))**0.6))

x = np.linspace(1,10)
y = wind_density_GJ1132(x)

plt.plot(x,y, label="wind density of GJ1132")
plt.legend(loc= 'lower right', bbox_to_anchor=(1.29, +0.12))
plt.title('wind density v. Age')
plt.xlabel('Age (Gyr)')
plt.ylabel('wind density(g/cm^3)')
# Out:
# Text(0, 0.5, 'wind density(g/cm^3)')

# %%
#wind density for GJ1214

def wind_density_GJ1214(T):
    return ((3.3E5*(2094400*10**5/r_sun)**-2 + 4.16E6*(2094400*10**5/r_sun)**-4 + 8.0E7*(2094400*10**5/r_sun)**-6)*(M_H/2)*((P_sun/((T-0.012)/0.061))**0.6))

x = np.linspace(1,10)
y = wind_density_GJ1214(x)

plt.plot(x,y, label="wind density of GJ1214")
plt.legend(loc= 'lower right', bbox_to_anchor=(1.29, +0.12))
plt.title('wind density v. Age')
plt.xlabel('Age (Gyr)')
plt.ylabel('wind density(g/cm^3)')
# Out:
# Text(0, 0.5, 'wind density(g/cm^3)')

# %%
#wind density for 55 Cnc

def wind_density_55Cnc(T):
    return ((3.3E5*(2303840*10**5/r_sun)**-2 + 4.16E6*(2303840*10**5/r_sun)**-4 + 8.0E7*(2303840*10**5/r_sun)**-6)*(M_H/2)*((P_sun/(25*((T/4.6)**1/2)))**0.6))


x = np.linspace(1,10)
y = wind_density_55Cnc(x)

plt.plot(x,y, label="wind density of 55Cnc")
plt.legend(loc= 'lower right', bbox_to_anchor=(1.29, +0.12))
plt.title('wind density v. Age')
plt.xlabel('Age (Gyr)')
plt.ylabel('wind density(g/cm^3)')
# Out:
# Text(0, 0.5, 'wind density(g/cm^3)')

# %%
x10 = np.linspace(1,10)
y10 = wind_density_GJ3053(x)

x11 = np.linspace(1,10)
y11 = wind_density_K218(x1)

x12 = np.linspace(1,10)
y12 = wind_density_Kepler138(x2)

x13 = np.linspace(1,10)
y13 = wind_density_K23d(x3)

x15 = np.linspace(1,10)
y15 = wind_density_GJ9827(x5)

x16 = np.linspace(1,10)
y16 = wind_density_GJ97658(x6)

x17 = np.linspace(1,10)
y17 = wind_density_GJ1132(x7)

x18 = np.linspace(1,10)
y18 = wind_density_GJ1214(x8)

x19 = np.linspace(1,10)
y19 = wind_density_55Cnc(x9)

x14 = np.linspace(1,10)
y14 = wind_density_K23c(x4)

axes= plt.axes()

plt.plot(x15,y15, label="GJ 9827")
plt.plot(x19,y19,label= "55 Cnc")
plt.plot(x16,y16, label= "GJ 97658")
plt.plot(x11,y11, label='K2-18')
plt.plot(x13,y13,label="K2-3d")
plt.plot(x17,y17,label='GJ 1132')
plt.plot(x18,y18,label='GJ 1214')
plt.plot(x12,y12,label='Kepler-138')
plt.plot(x10,y10,label='GJ-3053')
plt.plot(x14,y14,label="K2-3c")

plt.legend(loc= 'lower right', bbox_to_anchor=(1.29, +0.12))
plt.title('Wind density v. Age')
plt.xlabel('Age (Gyr)')
plt.ylabel('Wind Density (g/cm$^3$)')
plt.yscale('log')

# %%
#CALCULATING MASS LOSS RATES!

# %%
#Mass_loss_rates= 6.28*(plt_rad_km**2)*0.3*(wind_density*10**15)*(wind velocity)

# %%
def mass_loss_rate_GJ3053(T):
    return  6.28*(10958.1**2)*0.3*((((3.3E5*(14002560*10**5/r_sun)**-2 + 4.16E6*(14002560*10**5/r_sun)**-4 + 8.0E7*(14002560*10**5/r_sun)**-6)*(M_H/2)*((P_sun/((T-0.012)/0.061))**0.6)))*(10**15))*(2*(180*((1.5*(27/((T-0.012)/0.061))**1.2)*10**6/(2*10**6))**(1/2))*np.log(14002560*10**5/((2*10**11)*(0.179/1)*((1.5*(27/((T-0.012)/0.061))**1.2)*10**6/(2*10**6))**(-1)))**0.5)

x = np.linspace(1, 10)
y = mass_loss_rate_GJ3053(x)

plt.plot(x,y, label="mass loss rate of GJ3053b")
plt.legend(loc= 'lower right', bbox_to_anchor=(1.29, +0.12))
plt.title('Mass Loss v. Age')
plt.xlabel('Age (Gyr)')
plt.ylabel('Mass Loss(g/s)')
# Out:
# Text(0, 0.5, 'Mass Loss(g/s)')

# %%
def mass_loss_rate_K218(T):
    return 6.28*(15099.3**2)*0.3*((((3.3E5*(21377840*10**5/r_sun)**-2 + 4.16E6*(21377840*10**5/r_sun)**-4 + 8.0E7*(21377840*10**5/r_sun)**-6)*(M_H/2)*((P_sun/((T-0.012)/0.061))**0.6)))*10**15)*(2*(180*((1.5*(27/((T-0.012)/0.061))**1.2)*10**6/(2*10**6))**(1/2))*np.log(21377840*10**5/((2*10**11)*(0.359/1)*((1.5*(27/((T-0.012)/0.061))**1.2)*10**6/(2*10**6))**(-1)))**0.5)

x = np.linspace(1, 10)
y = mass_loss_rate_K218(x)

plt.plot(x,y, label="mass loss rate of K218")
plt.legend(loc= 'lower right', bbox_to_anchor=(1.29, +0.12))
plt.title('Mass Loss v. Age')
plt.xlabel('Age (Gyr)')
plt.ylabel('Mass Loss(g/s)')
# Out:
# Text(0, 0.5, 'Mass Loss(g/s)')

# %%
def mass_loss_rate_Kepler138(T):
    return 6.28*(7708.91**2)*0.3*((((3.3E5*(18999200*10**5/r_sun)**-2 + 4.16E6*(18999200*10**5/r_sun)**-4 + 8.0E7*(18999200*10**5/r_sun)**-6)*(M_H/2)*((P_sun/(((T-0.365)/0.019)**(1/1.457)))**0.6)))*10**15)*(2*(180*((1.5*(27/((T-0.365)/0.019)**(1/1.457))**1.2)*10**6/(2*10**6))**(1/2))*np.log(18999200*10**5/((2*10**11)*(0.521/1)*((1.5*(27/((T-0.365)/0.019)**(1/1.457))**1.2)*10**6/(2*10**6))**(-1)))**0.5)

x = np.linspace(1, 10)
y = mass_loss_rate_Kepler138(x)

plt.plot(x,y, label="mass loss rate of Kepler-138")
plt.legend(loc= 'lower right', bbox_to_anchor=(1.29, +0.12))
plt.title('Mass Loss v. Age')
plt.xlabel('Age (Gyr)')
plt.ylabel('Mass Loss(g/s)')
# Out:
# Text(0, 0.5, 'Mass Loss(g/s)')

# %%
def mass_loss_rate_K23d(T):
    return 6.28*(10512.2**2)*0.3*((((3.3E5*(31266400*10**5/r_sun)**-2 + 4.16E6*(31266400*10**5/r_sun)**-4 + 8.0E7*(31266400*10**5/r_sun)**-6)*(M_H/2)*((P_sun/(((T-0.365)/0.019)**(1/1.457)))**0.6)))*10**15)*(2*(180*((1.5*(27/((T-0.365)/0.019)**(1/1.457))**1.2)*10**6/(2*10**6))**(1/2))*np.log(31266400*10**5/((2*10**11)*(0.601/1)*((1.5*(27/((T-0.365)/0.019)**(1/1.457))**1.2)*10**6/(2*10**6))**(-1)))**0.5 )

x = np.linspace(1, 10)
y = mass_loss_rate_K23d(x)

plt.plot(x,y, label="mass loss rate of K2-3d")
plt.legend(loc= 'lower right', bbox_to_anchor=(1.29, +0.12))
plt.title('Mass Loss v. Age')
plt.xlabel('Age (Gyr)')
plt.ylabel('Mass Loss(g/s)')
# Out:
# Text(0, 0.5, 'Mass Loss(g/s)')

# %%
def mass_loss_rate_K23c(T):
    return 6.28*(11276.7**2)*0.3*((((3.3E5*(21138480*10**5/r_sun)**-2 + 4.16E6*(21138480*10**5/r_sun)**-4 + 8.0E7*(21138480*10**5/r_sun)**-6)*(M_H/2)*((P_sun/(((T-0.365)/0.019)**(1/1.457)))**0.6)))*10**15)*(2*(180*((1.5*(27/((T-0.365)/0.019)**(1/1.457))**1.2)*10**6/(2*10**6))**(1/2))*np.log(21138480*10**5/((2*10**11)*(0.601/1)*((1.5*(27/((T-0.365)/0.019)**(1/1.457))**1.2)*10**6/(2*10**6))**(-1)))**0.5)

x = np.linspace(1, 10)
y = mass_loss_rate_K23c(x)

plt.plot(x,y, label="mass loss rate of K2-3c")
plt.legend(loc= 'lower right', bbox_to_anchor=(1.29, +0.12))
plt.title('Mass Loss v. Age')
plt.xlabel('Age (Gyr)')
plt.ylabel('Mass Loss(g/s)')
# Out:
# Text(0, 0.5, 'Mass Loss(g/s)')

# %%
def mass_loss_rate_GJ9827(T):
    return 6.28*(12882.2**2)*0.3*((((3.3E5*(8228000*10**5/r_sun)**-2 + 4.16E6*(8228000*10**5/r_sun)**-4 + 8.0E7*(8228000*10**5/r_sun)**-6)*(M_H/2)*((P_sun/(25*((T/4.6)**1/2)))**0.6)))*10**15)*(2*(180*((1.98*(27/(25*((T/4.6)**1/2)))**0.37)*10**6/(2*10**6))**(1/2))*np.log(8228000*10**5/((2*10**11)*(0.606/1)*((1.98*(27/(25*((T/4.6)**1/2)))**0.37)*10**6/(2*10**6))**(-1)))**0.5 )

x = np.linspace(1, 10)
y = mass_loss_rate_GJ9827(x)

plt.plot(x,y, label="mass loss rate of GJ-9827")
plt.legend(loc= 'lower right', bbox_to_anchor=(1.29, +0.12))
plt.title('Mass Loss v. Age')
plt.xlabel('Age (Gyr)')
plt.ylabel('Mass Loss(g/s)')
# Out:
# Text(0, 0.5, 'Mass Loss(g/s)')

# %%
def mass_loss_rate_GJ97658(T):
    return 6.28*(15290.4**2)*0.3*((((3.3E5*(11968000*10**5/r_sun)**-2 + 4.16E6*(11968000*10**5/r_sun)**-4 + 8.0E7*(11968000*10**5/r_sun)**-6)*(M_H/2)*((P_sun/(25*((T/4.6)**1/2)))**0.6)))*10**15)*(2*(180*((1.5*(27/(25*((T/4.6)**1/2)))**1.2)*10**6/(2*10**6))**(1/2))*np.log(11968000*10**5/((2*10**11)*(0.85/1)*((1.5*(27/(25*((T/4.6)**1/2)))**1.2)*10**6/(2*10**6))**(-1)))**0.5 )

x = np.linspace(1, 10)
y = mass_loss_rate_GJ97658(x)

plt.plot(x,y, label="mass loss rate of GJ-97658")
plt.legend(loc= 'lower right', bbox_to_anchor=(1.29, +0.12))
plt.title('Mass Loss v. Age')
plt.xlabel('Age (Gyr)')
plt.ylabel('Mass Loss(g/s)')
# Out:
# Text(0, 0.5, 'Mass Loss(g/s)')

# %%
def mass_loss_rate_GJ1132(T):
    return 6.28*(7199.23**2)*0.3*((((3.3E5*(2094400*10**5/r_sun)**-2 + 4.16E6*(2094400*10**5/r_sun)**-4 + 8.0E7*(2094400*10**5/r_sun)**-6)*(M_H/2)*((P_sun/((T-0.012)/0.061))**0.6)))*10**15)*((180*((1.5*(27/((T-0.012)/0.061))**1.2)*10**6/(2*10**6))**(1/2))*np.exp(3/2)*np.exp((-2*((2*10**11)*(0.181/1)*((1.5*(27/((T-0.012)/0.061))**1.2)*10**6/(2*10**6))**(-1)))/(2288880*10**5)))

x = np.linspace(1,10)
y = mass_loss_rate_GJ1132(x)

plt.plot(x,y, label="mass loss rate of GJ-1132")
plt.legend(loc= 'lower right', bbox_to_anchor=(1.29, +0.12))
plt.title('Mass Loss v. Age')
plt.xlabel('Age (Gyr)')
plt.ylabel('Mass Loss(g/s)')
# Out:
# Text(0, 0.5, 'Mass Loss(g/s)')

# %%
def mass_loss_rate_GJ1214(T):
    return 6.28*(18157.4**2)*0.3*((((3.3E5*(2094400*10**5/r_sun)**-2 + 4.16E6*(2094400*10**5/r_sun)**-4 + 8.0E7*(2094400*10**5/r_sun)**-6)*(M_H/2)*((P_sun/((T-0.012)/0.061))**0.6)))*10**15)*((180*((1.5*(27/((T-0.012)/0.061))**1.2)*10**6/(2*10**6))**(1/2))*np.exp(3/2)*np.exp((-2*((2*10**11)*(0.15/1)*((1.5*(27/((T-0.012)/0.061))**1.2)*10**6/(2*10**6))**(-1)))/(2094400*10**5)))

x = np.linspace(1,10)
y = mass_loss_rate_GJ1214(x)

plt.plot(x,y, label="mass loss rate of GJ-1214")
plt.legend(loc= 'lower right', bbox_to_anchor=(1.29, +0.12))
plt.title('Mass Loss v. Age')
plt.xlabel('Age (Gyr)')
plt.ylabel('Mass Loss(g/s)')
# Out:
# Text(0, 0.5, 'Mass Loss(g/s)')

# %%
def mass_loss_rate_55Cnc(T):
    return 6.28*(12168.6**2)*0.3*((((3.3E5*(2303840*10**5/r_sun)**-2 + 4.16E6*(2303840*10**5/r_sun)**-4 + 8.0E7*(2303840*10**5/r_sun)**-6)*(M_H/2)*((P_sun/(25*((T/4.6)**1/2)))**0.6)))*10**15)*((180*((1.5*(27/(25*((T/4.6)**1/2)))**1.2)*10**6/(2*10**6))**(1/2))*np.exp(3/2)*np.exp((-2*((2*10**11)*(0.905/1)*((1.5*(27/(25*((T/4.6)**1/2)))**1.2)*10**6/(2*10**6))**(-1)))/(2303840*10**5)))

x = np.linspace(1,10)
y = mass_loss_rate_55Cnc(x)

plt.plot(x,y, label="mass loss rate of 55Cnc")
plt.legend(loc= 'lower right', bbox_to_anchor=(1.29, +0.12))
plt.title('Mass Loss v. Age')
plt.xlabel('Age (Gyr)')
plt.ylabel('Mass Loss(g/s)')
# Out:
# Text(0, 0.5, 'Mass Loss(g/s)')

# %%
x20 = np.linspace(1,10)
y20 = mass_loss_rate_GJ3053(x)

x21 = np.linspace(1,10)
y21 = mass_loss_rate_K218(x1)

x22 = np.linspace(1,10)
y22 = mass_loss_rate_Kepler138(x2)

x23 = np.linspace(1,10)
y23 = mass_loss_rate_K23d(x3)

x25 = np.linspace(1,10)
y25 = mass_loss_rate_GJ9827(x5)

x26 = np.linspace(1,10)
y26 = mass_loss_rate_GJ97658(x6)

x27 = np.linspace(1,10)
y27 = mass_loss_rate_GJ1132(x7)

x28 = np.linspace(1,10)
y28 = mass_loss_rate_GJ1214(x8)

x29 = np.linspace(1,10)
y29 = mass_loss_rate_55Cnc(x9)

x24 = np.linspace(1,10)
y24 = mass_loss_rate_K23c(x4)

axes= plt.axes()

plt.plot(x25,y25, label="GJ 9827")
plt.plot(x29,y29,label= "55 Cnc")
plt.plot(x26,y26, label= "GJ 97658")
plt.plot(x21,y21, label='K2-18')
plt.plot(x23,y23,label="K2-3d")
plt.plot(x27,y27,label='GJ 1132')
plt.plot(x28,y28,label='GJ 1214')
plt.plot(x22,y22,label='Kepler-138')
plt.plot(x20,y20,label='GJ-3053')
plt.plot(x24,y24,label="K2-3c")

plt.legend(loc= 'lower right', bbox_to_anchor=(1.29, +0.12))
plt.title('Mass Loss v. Age')
plt.xlabel('Age (Gyr)')
plt.ylabel('Mass Loss (g/s)')
plt.yscale('log')
